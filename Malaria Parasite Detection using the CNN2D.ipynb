# %% [markdown]
# - Maleria is an infectius disease that couses over the 40000 deah per years.
#
# - Mosquitoes are notorious for carrying maleria.
#
# - In 2008,Rajaraman et Al. published papar entitled pretrained covoluatinal Neural networks as feature extractors towards improved parasite detection in thin blood smear images.
#
# - This page hosts a repository of segmented cells from the thin blood smear slide images from the Malaria Screener research activity. To reduce the burden for microscopists in resource-constrained regions and improve diagnostic accuracy.
# -  We applied a level-set based algorithm to detect and segment the red blood cells. The dataset contains a total of 27,558 cell images with equal instances of parasitized and uninfected cells.

# %%
from IPython.display import Image
Image(filename ='C:/Users/Microsoft/Desktop/DSMP/Previous-prevalence-of-malaria-world-map-800x386.png')

# %% [markdown]
# link :- https://lhncbc.nim.nih.gov/publication/pub9932

# %% [markdown]
# ## Images of Bood simears

# %%
from IPython.display import Image
Image(filename ='C:/Users/Microsoft/Desktop/DSMP/50046086-713da980-00c3-11e9-9c79-db215df220e2.jpg')

# %% [markdown]
# - By using this datasest we will gonna detection the person suffered by maleria or not.

# %%
# !git clone https://github.com/laxmimerit/Malaria-Classification-Using-CNN.git
# Out:
# 'git' is not recognized as an internal or external command,
# operable program or batch file.
